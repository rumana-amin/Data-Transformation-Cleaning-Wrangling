# %%
import pandas as pd
import os
import openpyxl

# %%
# Read Excel file into DataFrame
df = pd.read_excel('03-12.xlsx', header=None)
df.head(15)
# Out:
#                                                     0  \
# 0   NAME: \n                                      ...
# 1                                             ADRESS:
# 2                                              CITY:
# 3                                          PROVINCE:
# 4                                      POSTAL CODE:\n
# 5                                           COUNTRY:
# 6                                         TELEPHONE:
# 7   NAME: \n                                      ...
# 8                                             ADRESS:
# 9                                              CITY:
# 10                                         PROVINCE:
# 11                                     POSTAL CODE:\n
# 12                                          COUNTRY:
# 13                                        TELEPHONE:
# 14  NAME: \n                                      ...
#
#                                             1
# 0                        francisca lopez vera
# 1   calle herreria nº 27\ncalle herreria nº25
# 2                                  el burgo,
# 3                                     malaga
# 4                                       29420
# 5                                       spain
# 6                                   645465703
# 7                                     Miguel
# 8             Camino Ca'n Duran nº15 (PIVITA)
# 9             Palma de Mallorca (El Arenal),
# 10                             Illes Balears
# 11                                       7600
# 12                                      spain
# 13                                  658888909
# 14                               Miquel Pérez

# %%
# Pivot the DataFrame
df_pivoted = df.pivot(columns=df.columns[0], values=df.columns[1])
df_pivoted.head()
# Out:
# 0                                    ADRESS:      CITY:  COUNTRY:   \
# 0                                        NaN         NaN       NaN
# 1  calle herreria nº 27\ncalle herreria nº25         NaN       NaN
# 2                                        NaN  el burgo,        NaN
# 3                                        NaN         NaN       NaN
# 4                                        NaN         NaN       NaN
#
# 0 NAME: \n                                                                                      \
# 0                               francisca lopez vera
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# 0 POSTAL CODE:\n PROVINCE:  TELEPHONE:
# 0            NaN        NaN         NaN
# 1            NaN        NaN         NaN
# 2            NaN        NaN         NaN
# 3            NaN    malaga          NaN
# 4          29420        NaN         NaN

# %%
# Rename the columns
df_pivoted.columns = ['Address', 'City', 'Country', 'Name', 'Postal_code', 'Province', 'Telephone']

df_pivoted.head(17)
# Out:
#                                       Address  \
# 0                                         NaN
# 1   calle herreria nº 27\ncalle herreria nº25
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8             Camino Ca'n Duran nº15 (PIVITA)
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15         Passeig d'en Llull num. 41 casa3\n
# 16                                        NaN
#
#                                City Country                  Name Postal_code  \
# 0                               NaN     NaN  francisca lopez vera         NaN
# 1                               NaN     NaN                   NaN         NaN
# 2                        el burgo,      NaN                   NaN         NaN
# 3                               NaN     NaN                   NaN         NaN
# 4                               NaN     NaN                   NaN       29420
# 5                               NaN   spain                   NaN         NaN
# 6                               NaN     NaN                   NaN         NaN
# 7                               NaN     NaN               Miguel          NaN
# 8                               NaN     NaN                   NaN         NaN
# 9   Palma de Mallorca (El Arenal),      NaN                   NaN         NaN
# 10                              NaN     NaN                   NaN         NaN
# 11                              NaN     NaN                   NaN        7600
# 12                              NaN   spain                   NaN         NaN
# 13                              NaN     NaN                   NaN         NaN
# 14                              NaN     NaN          Miquel Pérez         NaN
# 15                              NaN     NaN                   NaN         NaN
# 16       Sant Andreu de Llavaneres,     NaN                   NaN         NaN
#
#           Province  Telephone
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3          malaga         NaN
# 4              NaN        NaN
# 5              NaN        NaN
# 6              NaN  645465703
# 7              NaN        NaN
# 8              NaN        NaN
# 9              NaN        NaN
# 10  Illes Balears         NaN
# 11             NaN        NaN
# 12             NaN        NaN
# 13             NaN  658888909
# 14             NaN        NaN
# 15             NaN        NaN
# 16             NaN        NaN

# %%
df_pivoted.tail(10)
# Out:
#     Address City Country Name Postal_code Province Telephone
# 543     NaN  NaN     NaN  NaN         NaN      NaN       NaN
# 544     NaN  NaN     NaN  NaN         NaN      NaN       NaN
# 545     NaN  NaN     NaN  NaN         NaN      NaN       NaN
# 546     NaN  NaN     NaN  NaN         NaN      NaN       NaN
# 547     NaN  NaN     NaN  NaN         NaN      NaN       NaN
# 548     NaN  NaN     NaN  NaN         NaN      NaN       NaN
# 549     NaN  NaN     NaN  NaN         NaN      NaN       NaN
# 550     NaN  NaN     NaN  NaN         NaN      NaN       NaN
# 551     NaN  NaN     NaN  NaN         NaN      NaN       NaN
# 552     NaN  NaN     NaN  NaN         NaN      NaN       NaN

# %%
# Drop rows with all NaN values
df_pivoted.dropna(axis=0, how='all', inplace=True)
df_pivoted.tail()
# Out:
#     Address               City Country Name Postal_code Province  Telephone
# 527     NaN  Torrejon de ardoz     NaN  NaN         NaN      NaN        NaN
# 528     NaN                NaN     NaN  NaN         NaN  Madrid         NaN
# 529     NaN                NaN     NaN  NaN       28850      NaN        NaN
# 530     NaN                NaN   spain  NaN         NaN      NaN        NaN
# 531     NaN                NaN     NaN  NaN         NaN      NaN  660505839

# %%
# To see the number of rows and columns of the df
df_pivoted.shape
# Out:
# (525, 7)

# %%
# back Filled the df replacing NaN Valus up to 6 rows
df_filled= df_pivoted.fillna(method="bfill", limit=6) # row index 0, 7, 13, 20, 27 
df_filled.tail(10)
# Out:
#                         Address               City Country  \
# 522  Avenida Constitución 108    Torrejon de ardoz   spain
# 523  Avenida Constitución 108    Torrejon de ardoz   spain
# 524  Avenida Constitución 108    Torrejon de ardoz   spain
# 525  Avenida Constitución 108    Torrejon de ardoz   spain
# 526  Avenida Constitución 108    Torrejon de ardoz   spain
# 527                         NaN  Torrejon de ardoz   spain
# 528                         NaN                NaN   spain
# 529                         NaN                NaN   spain
# 530                         NaN                NaN   spain
# 531                         NaN                NaN     NaN
#
#                                      Name Postal_code Province  Telephone
# 522  XCGUZMEO Ana Cristina Luengo Brioa\n       28400  Madrid   687939382
# 523  XCGUZMEO Ana Cristina Luengo Brioa\n       28850  Madrid   687939382
# 524  XCGUZMEO Ana Cristina Luengo Brioa\n       28850  Madrid   687939382
# 525  XCGUZMEO Ana Cristina Luengo Brioa\n       28850  Madrid   660505839
# 526                                   NaN       28850  Madrid   660505839
# 527                                   NaN       28850  Madrid   660505839
# 528                                   NaN       28850  Madrid   660505839
# 529                                   NaN       28850      NaN  660505839
# 530                                   NaN         NaN      NaN  660505839
# 531                                   NaN         NaN      NaN  660505839

# %%
# Containing only the rows with the specified index positions.
"""selected_rows = df_filled.iloc[[0, 7, 13, 20, 27]]
selected_rows"""
# Out:
# 'selected_rows = df_filled.iloc[[0, 7, 13, 20, 27]]\nselected_rows'

# %%
# Slicing with a step of 7.
df_selected_rows= df_filled.iloc[::7]
df_selected_rows.tail()
# Out:
#                              Address                City Country  \
# 497  Calle Angustias 34 2º Izquierda          Valladolid   spain
# 504         C/ MIGUEL DE CERVANTES,6            CHIPIONA   spain
# 511              Camino el Niquel 7             Tejina,    spain
# 518                Calle el Lagar 30  Collado Villalba,    spain
# 525       Avenida Constitución 108     Torrejon de ardoz   spain
#
#                                      Name Postal_code                Province  \
# 497           Pablo Alcalde Martin-Calero       47003              Valladolid
# 504         ANA VALERIANA GALVEZ GARCIA\n       11550                   CADIZ
# 511                Alicia González Molina       38260  Santa Cruz de Tenerife
# 518               Félix Luis Mendez Bravo       28400                 Madrid
# 525  XCGUZMEO Ana Cristina Luengo Brioa\n       28850                 Madrid
#
#         Telephone
# 497  34-629261318
# 504   34956370762
# 511     621395927
# 518     687939382
# 525     660505839

# %%
# Remove '\n' characters and extra spaces from the 'Name' column
df_selected_rows.loc[:,'Name'] = df_selected_rows['Name'].str.strip()
df_selected_rows.tail()
# Out:
#                              Address                City Country  \
# 497  Calle Angustias 34 2º Izquierda          Valladolid   spain
# 504         C/ MIGUEL DE CERVANTES,6            CHIPIONA   spain
# 511              Camino el Niquel 7             Tejina,    spain
# 518                Calle el Lagar 30  Collado Villalba,    spain
# 525       Avenida Constitución 108     Torrejon de ardoz   spain
#
#                                    Name Postal_code                Province  \
# 497         Pablo Alcalde Martin-Calero       47003              Valladolid
# 504         ANA VALERIANA GALVEZ GARCIA       11550                   CADIZ
# 511              Alicia González Molina       38260  Santa Cruz de Tenerife
# 518             Félix Luis Mendez Bravo       28400                 Madrid
# 525  XCGUZMEO Ana Cristina Luengo Brioa       28850                 Madrid
#
#         Telephone
# 497  34-629261318
# 504   34956370762
# 511     621395927
# 518     687939382
# 525     660505839

# %%
df_selected_rows.dtypes
# Out:
# Address        object
# City           object
# Country        object
# Name           object
# Postal_code    object
# Province       object
# Telephone      object
# dtype: object

# %%
# Define the desired column order
desired_columns = ['Name', 'Address', 'City', 'Province', 'Postal_code', 'Country', 'Telephone']

# Reorder the columns in the DataFrame
df_selected_rows = df_selected_rows.reindex(columns=desired_columns)

# Display the DataFrame with the reordered columns
df_selected_rows.head()
# Out:
#                           Name                                    Address  \
# 0         francisca lopez vera  calle herreria nº 27\ncalle herreria nº25
# 7                       Miguel            Camino Ca'n Duran nº15 (PIVITA)
# 14                Miquel Pérez         Passeig d'en Llull num. 41 casa3\n
# 21     David Benitez Rodriguez               Calle de los Hortelanos Nº21
# 28  miguel carlos diaz novillo                    calle pedro domeq N° 49
#
#                                City        Province Postal_code Country  \
# 0                        el burgo,          malaga        29420   spain
# 7   Palma de Mallorca (El Arenal),   Illes Balears         7600   spain
# 14       Sant Andreu de Llavaneres,      Barcelona         8392   spain
# 21             Morón de la Frontera        Sevilla        41530   spain
# 28                        Tomelloso    Ciudad Real        13700   spain
#
#     Telephone
# 0   645465703
# 7   658888909
# 14  610202792
# 21  696584365
# 28  695256217

# %%
# Reset the row index
df_selected_rows.reset_index(drop=True, inplace=True)

# Display the DataFrame with the reordered columns
df_selected_rows.head()
# Out:
#                          Name                                    Address  \
# 0        francisca lopez vera  calle herreria nº 27\ncalle herreria nº25
# 1                      Miguel            Camino Ca'n Duran nº15 (PIVITA)
# 2                Miquel Pérez         Passeig d'en Llull num. 41 casa3\n
# 3     David Benitez Rodriguez               Calle de los Hortelanos Nº21
# 4  miguel carlos diaz novillo                    calle pedro domeq N° 49
#
#                               City        Province Postal_code Country  \
# 0                       el burgo,          malaga        29420   spain
# 1  Palma de Mallorca (El Arenal),   Illes Balears         7600   spain
# 2       Sant Andreu de Llavaneres,      Barcelona         8392   spain
# 3             Morón de la Frontera        Sevilla        41530   spain
# 4                        Tomelloso    Ciudad Real        13700   spain
#
#    Telephone
# 0  645465703
# 1  658888909
# 2  610202792
# 3  696584365
# 4  695256217

# %%
df_selected_rows.shape
# Out:
# (75, 7)

# %%
# Importing the second df 
url = 'https://countrycode.org/'
tables = pd.read_html(url)
print(len(tables))
# Out:
# 2

# %%
df_code = tables[0]
df_code.head()
# Out:
#           COUNTRY COUNTRY CODE ISO CODES  POPULATION  AREA KM2       GDP $USD
# 0     Afghanistan           93  AF / AFG    29121286    647500  20.65 Billion
# 1         Albania          355  AL / ALB     2986952     28748   12.8 Billion
# 2         Algeria          213  DZ / DZA    34586184   2381740  215.7 Billion
# 3  American Samoa        1-684  AS / ASM       57881       199  462.2 Million
# 4         Andorra          376  AD / AND       84000       468    4.8 Billion

# %%
# Convert the case of the merge keys
df_code["COUNTRY"] = df_code["COUNTRY"].str.lower()

# %%
df_merged = pd.merge(df_selected_rows, df_code , left_on="Country", right_on="COUNTRY", how="left")
df_merged.tail()
# Out:
#                                   Name                          Address  \
# 70         Pablo Alcalde Martin-Calero  Calle Angustias 34 2º Izquierda
# 71         ANA VALERIANA GALVEZ GARCIA         C/ MIGUEL DE CERVANTES,6
# 72              Alicia González Molina              Camino el Niquel 7
# 73             Félix Luis Mendez Bravo                Calle el Lagar 30
# 74  XCGUZMEO Ana Cristina Luengo Brioa       Avenida Constitución 108
#
#                   City                Province Postal_code Country  \
# 70          Valladolid              Valladolid       47003   spain
# 71            CHIPIONA                   CADIZ       11550   spain
# 72            Tejina,   Santa Cruz de Tenerife       38260   spain
# 73  Collado Villalba,                  Madrid        28400   spain
# 74   Torrejon de ardoz                 Madrid        28850   spain
#
#        Telephone COUNTRY COUNTRY CODE ISO CODES  POPULATION  AREA KM2  \
# 70  34-629261318   spain           34  ES / ESP    46505963    504782
# 71   34956370762   spain           34  ES / ESP    46505963    504782
# 72     621395927   spain           34  ES / ESP    46505963    504782
# 73     687939382   spain           34  ES / ESP    46505963    504782
# 74     660505839   spain           34  ES / ESP    46505963    504782
#
#           GDP $USD
# 70  1.356 Trillion
# 71  1.356 Trillion
# 72  1.356 Trillion
# 73  1.356 Trillion
# 74  1.356 Trillion

# %%
# Drop the 'COUNTRY' column and the last four columns from the merged DataFrame
df_merged.drop(columns=['COUNTRY'] + list(df_merged.columns[-4:]), axis=1, inplace=True)
df_merged.head()
# Out:
#                          Name                                    Address  \
# 0        francisca lopez vera  calle herreria nº 27\ncalle herreria nº25
# 1                      Miguel            Camino Ca'n Duran nº15 (PIVITA)
# 2                Miquel Pérez         Passeig d'en Llull num. 41 casa3\n
# 3     David Benitez Rodriguez               Calle de los Hortelanos Nº21
# 4  miguel carlos diaz novillo                    calle pedro domeq N° 49
#
#                               City        Province Postal_code Country  \
# 0                       el burgo,          malaga        29420   spain
# 1  Palma de Mallorca (El Arenal),   Illes Balears         7600   spain
# 2       Sant Andreu de Llavaneres,      Barcelona         8392   spain
# 3             Morón de la Frontera        Sevilla        41530   spain
# 4                        Tomelloso    Ciudad Real        13700   spain
#
#    Telephone COUNTRY CODE
# 0  645465703           34
# 1  658888909           34
# 2  610202792           34
# 3  696584365           34
# 4  695256217           34

# %%
# Define the desired column order
desired_columns_final = ['Name', 'Address', 'City', 'Province', 'Postal_code', 'Country', 'COUNTRY CODE', 'Telephone']

# Reorder the columns in the DataFrame
df_final = df_merged.reindex(columns=desired_columns_final)

# Display the DataFrame with the reordered columns
df_final.head()
# Out:
#                          Name                                    Address  \
# 0        francisca lopez vera  calle herreria nº 27\ncalle herreria nº25
# 1                      Miguel            Camino Ca'n Duran nº15 (PIVITA)
# 2                Miquel Pérez         Passeig d'en Llull num. 41 casa3\n
# 3     David Benitez Rodriguez               Calle de los Hortelanos Nº21
# 4  miguel carlos diaz novillo                    calle pedro domeq N° 49
#
#                               City        Province Postal_code Country  \
# 0                       el burgo,          malaga        29420   spain
# 1  Palma de Mallorca (El Arenal),   Illes Balears         7600   spain
# 2       Sant Andreu de Llavaneres,      Barcelona         8392   spain
# 3             Morón de la Frontera        Sevilla        41530   spain
# 4                        Tomelloso    Ciudad Real        13700   spain
#
#   COUNTRY CODE  Telephone
# 0           34  645465703
# 1           34  658888909
# 2           34  610202792
# 3           34  696584365
# 4           34  695256217

# %%
# Merge two columns into one column
# Concatenate 'COUNTRY CODE' and 'Telephone' columns into 'Telephone_code' column
df_merged['Telephone_code'] = df_merged['COUNTRY CODE'].astype(str) + '-' + df_merged['Telephone'].astype(str)

# Drop the 'COUNTRY CODE' and 'Telephone' columns
df_merged.drop(columns=['COUNTRY CODE', 'Telephone'], inplace=True)

df_merged.head()
# Out:
#                          Name                                    Address  \
# 0        francisca lopez vera  calle herreria nº 27\ncalle herreria nº25
# 1                      Miguel            Camino Ca'n Duran nº15 (PIVITA)
# 2                Miquel Pérez         Passeig d'en Llull num. 41 casa3\n
# 3     David Benitez Rodriguez               Calle de los Hortelanos Nº21
# 4  miguel carlos diaz novillo                    calle pedro domeq N° 49
#
#                               City        Province Postal_code Country  \
# 0                       el burgo,          malaga        29420   spain
# 1  Palma de Mallorca (El Arenal),   Illes Balears         7600   spain
# 2       Sant Andreu de Llavaneres,      Barcelona         8392   spain
# 3             Morón de la Frontera        Sevilla        41530   spain
# 4                        Tomelloso    Ciudad Real        13700   spain
#
#   Telephone_code
# 0   34-645465703
# 1   34-658888909
# 2   34-610202792
# 3   34-696584365
# 4   34-695256217

# %%
# save to CSV without the index
df_merged.to_csv('output_data.csv', index = False)
